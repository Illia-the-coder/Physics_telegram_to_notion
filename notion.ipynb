# %%
import os
import csv
from notion_client import Client
import pandas as pd

# Initialize Notion API client
notion = Client(auth=os.environ['NOTION_TOKEN'])

# %%
# Replace 'your_database_id' with the ID of your database
database_id = os.environ['NOTION_DATABASE_ID']

# Query the database
results = notion.databases.query(database_id=database_id)

# %%
# Extract the data
data = []
columns = results["results"][0]["properties"].keys()

for page in results["results"]:
    row = {}
    row['id'] = page["id"]
    for column in columns:
        property_type = page["properties"][column]["type"]
        if property_type in page["properties"][column]:
            row[column] = page["properties"][column][property_type]
        else:
            row[column] = ""
    data.append(row)

# Write the data to a CSV file
df = pd.DataFrame(data)
df.to_csv("notion_database.csv", index=False, quoting=csv.QUOTE_NONNUMERIC)

print("Notion database exported as 'notion_database.csv'")
# Out:
# Notion database exported as 'notion_database.csv'

# %%
df.head()
# Out:
#                                      id
# 0  00639d45-b5a8-4905-8da2-f5cecf1df6d4  \
# 1  03c2f16b-749b-444a-b8e8-8247d99d7278
# 2  04799351-fe47-4a05-bf07-db4e9a35352d
# 3  18fe44d5-3d30-41f2-888b-af2671e5eaf8
# 4  229f976e-a681-4a7e-9474-94ddb41c51c7
#
#                                                 Тема  Lesson
# 0  {'id': 'muy@', 'name': 'МАГНІТНІ ЯВИЩА', 'colo...    True  \
# 1  {'id': ']|Ji', 'name': 'ФІЗИКА АТОМА', 'color'...    True
# 2  {'id': 'oGlL', 'name': 'ЗАКОНИ ЗБЕРЕЖЕННЯ', 'c...    True
# 3  {'id': 'cqME', 'name': 'МЕХАНІЧНІ ТА Е\М КОЛИВ...   False
# 4  {'id': 'KrTP', 'name': 'СВІТЛОВІ ЯВИЩА', 'colo...    True
#
#                     Created
# 0  2023-04-12T15:07:00.000Z  \
# 1  2023-04-12T15:07:00.000Z
# 2  2023-04-12T15:07:00.000Z
# 3  2023-04-12T15:07:00.000Z
# 4  2023-04-12T15:07:00.000Z
#
#                                                 Date
# 0  {'start': '2022-09-09', 'end': None, 'time_zon...  \
# 1  {'start': '2023-01-20', 'end': None, 'time_zon...
# 2  {'start': '2023-04-19', 'end': None, 'time_zon...
# 3  {'start': '2022-12-21', 'end': None, 'time_zon...
# 4  {'start': '2022-11-09', 'end': None, 'time_zon...
#
#                                                 Name
# 0  [{'type': 'text', 'text': {'content': 'Гіпотез...
# 1  [{'type': 'text', 'text': {'content': 'Протонн...
# 2  [{'type': 'text', 'text': {'content': 'Розв’яз...
# 3  [{'type': 'text', 'text': {'content': 'Контрол...
# 4  [{'type': 'text', 'text': {'content': 'Інструк...

# %%
df['Date'] = df['Date'].apply(lambda x: x['start'])
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d')
df=df[['Date','id','Lesson']]
df.head()
# Out:
#         Date                                    id  Lesson
# 0 2022-09-09  00639d45-b5a8-4905-8da2-f5cecf1df6d4    True
# 1 2023-01-20  03c2f16b-749b-444a-b8e8-8247d99d7278    True
# 2 2023-04-19  04799351-fe47-4a05-bf07-db4e9a35352d    True
# 3 2022-12-21  18fe44d5-3d30-41f2-888b-af2671e5eaf8   False
# 4 2022-11-09  229f976e-a681-4a7e-9474-94ddb41c51c7    True

# %%
# df Date before today
df['month'] = df['Date'].dt.month
df=df.sort_values(by=['Date'])
df[df['Date']<=pd.to_datetime('today')]
# Out:
#          Date                                    id  Lesson  month
# 11 2022-09-07  75b6545a-5e14-4bcb-9041-b84efcdbc24a    True      9
# 0  2022-09-09  00639d45-b5a8-4905-8da2-f5cecf1df6d4    True      9
# 10 2022-09-14  7247d640-dbd9-40b2-9ed8-eff339ba7604   False      9
# 12 2022-09-16  7c9ffe6a-4841-4f0a-bc47-43e05cd17fea    True      9
# 54 2022-09-21  9364a94e-7efb-4d91-80d7-07f25f0104fa    True      9
# 23 2022-09-23  68e1d363-1bd4-4123-a61e-c4f192577f09    True      9
# 60 2022-09-28  dfc2f589-399c-446d-9dc9-849085417056    True      9
# 13 2022-09-30  7face4af-31a8-4226-8af2-a06ace908ec8    True      9
# 56 2022-10-05  9b93d2b6-40be-4517-955a-d786f7e431d8   False     10
# 38 2022-10-07  6f9ef1e8-1bac-47f6-a87d-f977c53bbe0e    True     10
# 16 2022-10-12  b37d9c0a-f313-4d14-9abf-28ff7ca538b4    True     10
# 63 2022-10-14  199964da-9b36-427f-9c68-070fd95ff407    True     10
# 27 2022-10-19  88f5c85e-b142-4807-b2aa-bfa9f3516ed1    True     10
# 20 2022-10-21  3fcb8bf9-2724-4438-b4c8-f1c84cce76d3    True     10
# 61 2022-11-02  e6515b88-dcb5-45eb-acc9-65650dc70080    True     11
# 35 2022-11-04  24c54d90-a7c8-4079-a45c-cdedfd74b154   False     11
# 4  2022-11-09  229f976e-a681-4a7e-9474-94ddb41c51c7    True     11
# 5  2022-11-11  45bc8173-058e-4efc-81d0-f492266165fd    True     11
# 46 2022-11-16  ceef73b1-744c-4db4-be44-ddab9ecce47c    True     11
# 64 2022-11-18  30806e1a-a031-46b6-86c0-971543050fb6    True     11
# 42 2022-11-23  8b238b10-576e-4e05-996e-ba4560c879a7    True     11
# 34 2022-11-25  f3c61d92-dfac-4402-b46b-a2effa390eea    True     11
# 24 2022-11-30  699c2803-6687-4bd9-bb53-078d4c86eae6    True     11
# 26 2022-12-02  8376aead-3aa1-49dc-8d12-7085b428c073    True     12
